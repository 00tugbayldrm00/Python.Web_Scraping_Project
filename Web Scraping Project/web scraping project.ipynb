# %%
import requests
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

from urllib import robotparser

url = "https://www.gratis.com/robots.txt"

try:
    r = requests.get(url, verify= False)
    robots_txt = r.text

    rp= robotparser.RobotFileParser()
    rp.parse(robots_txt.splitlines())
    print("ürün izni:", rp.can_fetch("*","/product/some-product-slug"))

except requests.exceptions.RequestException as e:
                        print("hata:", e)
# Out:
# ürün izni: True

# %%
from bs4 import BeautifulSoup
import smtplib
import time
import datetime

# %%
URL = 'https://www.gratis.com/yuz-serumlari-cilt-serumu-yaglari/maruderm-yag-bazli-temizleyici-yuz-ve-vucut-icin-temizleme-yagi-400-ml-p-10590219'
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0"}

# %%
page = requests.get(URL, headers=headers, verify=False)

# %%
soup1 = BeautifulSoup(page.content , "html.parser")

# %%
soup2 = BeautifulSoup(soup1.prettify(),"html.parser")

# %%
title = soup2.find("h1", class_="text-[28px] leading-10 font-semibold text-primary-900").get_text().strip()
print(title)
# Out:
# Maruderm Yağ Bazlı Temizleyici Yüz ve Vücut İçin Temizleme Yağı 400 ml

# %%
price = soup2.find("p", class_ = "text-[32px] font-bold leading-[44.8px] text-primary-850 mb-5").get_text().strip()
print(price)
# Out:
# 338,00 TL

# %%
print(title)
print(price)
# Out:
# Maruderm Yağ Bazlı Temizleyici Yüz ve Vücut İçin Temizleme Yağı 400 ml
# 338,00 TL

# %%
price = price.replace("TL", "").strip()

print(price)
# Out:
# 338,00

# %%
import datetime

# %%
today = datetime.date.today()
print(today)
# Out:
# 2025-10-21

# %%
import csv

# %%
header = ['Ürün', 'Fiyat', 'Tarih']
data = [title , price, today]

# %%
with open('Gratis ürün takibi projesi.csv', 'w', newline='', encoding='utf-8-sig') as file:
    writer= csv.writer(file)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\elizm\Gratis ürün takibi projesi.csv")
print(df)
# Out:
#                                                 Ürün   Fiyat       Tarih
# 0  Maruderm Yağ Bazlı Temizleyici Yüz ve Vücut İç...  338,00  2025-10-21

# %%
with open('Gratis ürün takibi projesi.csv', 'a+', newline='', encoding='utf-8-sig') as file:
    writer = csv.writer(file)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.gratis.com/yuz-serumlari-cilt-serumu-yaglari/maruderm-yag-bazli-temizleyici-yuz-ve-vucut-icin-temizleme-yagi-400-ml-p-10590219'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/141.0.0.0 Safari/537.36 Edg/141.0.0.0"}
    page = requests.get(URL, headers=headers, verify=False)
    soup1 = BeautifulSoup(page.content , "html.parser")
    soup2 = BeautifulSoup(soup1.prettify(),"html.parser")
    title = soup2.find("h1", class_="text-[28px] leading-10 font-semibold text-primary-900").get_text().strip()
    price = soup2.find("p", class_ = "text-[32px] font-bold leading-[44.8px] text-primary-850 mb-5").get_text().strip()
    price = price.replace("TL", "").strip()

    import datetime
    today = datetime.date.today()

    import csv
    df = pd.read_csv(r"C:\Users\elizm\Gratis ürün takibi projesi.csv")

    with open('Gratis ürün takibi projesi.csv', 'a+', newline='', encoding='utf-8-sig') as file:
        writer = csv.writer(file)
        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(86400)

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\elizm\Gratis ürün takibi projesi.csv")
print(df)

# %%
if(price<200,00):
    send_mail()

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('gmail_hesabın', 'şifren')

    subject = "İstediğin ürün ucuzladı"
    body = "Koş al ne bekliyorsun"

    msg= f"Subject: {subject}\n\n{body}"

    server.sendmail(
        'mailin',
        msg
    )
